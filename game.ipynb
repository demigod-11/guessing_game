# %%
# Out:
# calling less
# calling less
# calling large
# calling large
# calling large
# Found
# calling large
# calling less
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# calling large
# Found
# ...

# %%
# Out:
# 47
